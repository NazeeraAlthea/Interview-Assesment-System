# %%
from ultralytics import YOLO

# YOLOv8n = nano version, paling cepat untuk CPU
model = YOLO("yolov8n.pt")

print("YOLOv8n pretrained model loaded!")
# Out:
# YOLOv8n pretrained model loaded!

# %%
import os

VIDEO_DIR = "../../../data"  

exts = [".mp4", ".avi", ".mov", ".mkv", ".webm"]

video_files = [
    f for f in os.listdir(VIDEO_DIR)
    if os.path.splitext(f)[1].lower() in exts
]

print("Video ditemukan:", len(video_files))
video_files
# Out:
# Video ditemukan: 7
# ['interview_question_1.webm',
#  'interview_question_2.webm',
#  'interview_question_3.webm',
#  'interview_question_4.webm',
#  'interview_question_5.webm',
#  'wawancara1.mp4',
#  'wawancara2.mp4']

# %%
import matplotlib.pyplot as plt

def show_frame(frame, title=""):
    plt.figure(figsize=(8, 8))
    plt.title(title)
    plt.imshow(frame[:, :, ::-1])  # BGR → RGB
    plt.axis("off")
    plt.show()

# %%
import cv2
import pandas as pd

results_summary = []

vid_name = "interview_question_1.webm"
video_path = os.path.join(VIDEO_DIR, vid_name)

print(f"\nProcessing video: {vid_name}")

cap = cv2.VideoCapture(video_path)

frame_id = 0
frame_rate = cap.get(cv2.CAP_PROP_FPS)  # fps video
print("FPS:", frame_rate)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame_id += 1

    # YOLO inference
    results = model(frame)[0]

    # Count persons
    person_count = sum(1 for box in results.boxes if int(box.cls[0]) == 0)

    # Hitung timestamp (dalam detik)
    timestamp_sec = frame_id / frame_rate

    results_summary.append({
        "video": vid_name,
        "frame": frame_id,
        "timestamp_sec": timestamp_sec,
        "person_count": person_count,
    })

cap.release()
print("\nSelesai memproses video!")

# --- Convert ke dataframe
df = pd.DataFrame(results_summary)

# --- Filter orang > 1
df_multi_person = df[df["person_count"] > 1]

df_multi_person
# Out:
# Processing video: interview_question_1.webm
# FPS: 16.583333333333332
#
# 0: 384x640 1 person, 1 chair, 80.7ms
# Speed: 22.2ms preprocess, 80.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.9ms
# Speed: 1.8ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.2ms
# Speed: 1.1ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.2ms
# Speed: 1.1ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.3ms
# Speed: 1.1ms preprocess, 54.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.1ms
# Speed: 1.1ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.4ms
# Speed: 1.1ms preprocess, 56.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.0ms
# Speed: 1.1ms preprocess, 55.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 58.1ms
# Speed: 1.1ms preprocess, 58.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 58.7ms
# Speed: 1.3ms preprocess, 58.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.9ms
# Speed: 1.2ms preprocess, 55.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 61.2ms
# Speed: 1.0ms preprocess, 61.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 62.7ms
# Speed: 1.2ms preprocess, 62.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.6ms
# Speed: 1.2ms preprocess, 53.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.8ms
# Speed: 1.1ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.5ms
# Speed: 1.1ms preprocess, 53.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.1ms
# Speed: 1.1ms preprocess, 56.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 64.7ms
# Speed: 1.3ms preprocess, 64.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.5ms
# Speed: 1.1ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 62.4ms
# Speed: 1.1ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55
9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 62.9ms
# Speed: 1.2ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.8ms
# Speed: 1.1ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.9ms
# Speed: 1.1ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.6ms
# Speed: 1.1ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 58.7ms
# Speed: 1.2ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.6ms
# Speed: 1.2ms preprocess, 54.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.1ms
# Speed: 1.1ms preprocess, 54.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 50.5ms
# Speed: 1.1ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.4ms
# Speed: 1.2ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.2ms
# Speed: 1.2ms preprocess, 53.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.2ms
# Speed: 1.2ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.0ms
# Speed: 1.1ms preprocess, 51.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.2ms
# Speed: 1.3ms preprocess, 51.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.9ms
# Speed: 1.0ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 82.3ms
# Speed: 1.1ms preprocess, 82.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.7ms
# Speed: 1.4ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.2ms
# Speed: 1.3ms preprocess, 52.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.0ms
# Speed: 1.1ms preprocess, 52.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.6ms
# Speed: 1.1ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.4ms
# Speed: 1.1ms preprocess, 52.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.0ms
# Speed: 1.1ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.1ms
# Speed: 1.1ms preprocess, 53.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 49.1ms
# Speed: 1.0ms preprocess, 49.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 49.8ms
# Speed: 1.1ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.4ms
# Speed: 1.1ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.9ms
# Speed: 1.0ms preprocess, 53.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 53.8ms
# Speed: 1.1ms preprocess, 53.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.3ms
# Speed: 1.1ms preprocess, 52.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.2ms
# Speed: 1.1ms preprocess, 51.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 1 person, 1 chair, 64.2ms
# Speed: 1.5ms preprocess, 64.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 67.5ms
# Speed: 1.6ms preprocess, 67.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 68.3ms
# Speed: 1.0ms preprocess, 68.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 68.4ms
# Speed: 1.1ms preprocess, 68.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 68.5ms
# Speed: 1.0ms preprocess, 68.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 69.1ms
# Speed: 1.0ms preprocess, 69.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 62.4ms
# Speed: 1.1ms preprocess, 62.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 67.8ms
# Speed: 1.7ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 74.5ms
# Speed: 1.1ms preprocess, 74.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 58.3ms
# Speed: 1.0ms preprocess, 58.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 67.3ms
# Speed: 1.2ms preprocess, 67.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 59.8ms
# Speed: 1.2ms preprocess, 59.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 57.3ms
# Speed: 1.3ms preprocess, 57.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 57.5ms
# Speed: 1.2ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.7ms
# Speed: 1.2ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 57.0ms
# Speed: 1.2ms preprocess, 57.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 71.5ms
# Speed: 1.2ms preprocess, 71.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 57.1ms
# Speed: 1.0ms preprocess, 57.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.9ms
# Speed: 1.1ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 57.3ms
# Speed: 1.2ms preprocess, 57.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54
2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.7ms
# Speed: 1.1ms preprocess, 54.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 70.6ms
# Speed: 1.3ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 51.1ms
# Speed: 1.0ms preprocess, 51.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 97.1ms
# Speed: 2.1ms preprocess, 97.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 57.9ms
# Speed: 1.3ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.5ms
# Speed: 1.1ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 71.4ms
# Speed: 1.0ms preprocess, 71.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.0ms
# Speed: 1.6ms preprocess, 56.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.4ms
# Speed: 1.1ms preprocess, 56.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 74.1ms
# Speed: 1.1ms preprocess, 74.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 60.8ms
# Speed: 1.1ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.5ms
# Speed: 1.1ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.9ms
# Speed: 1.2ms preprocess, 56.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.0ms
# Speed: 1.0ms preprocess, 54.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 61.7ms
# Speed: 1.1ms preprocess, 61.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.3ms
# Speed: 1.1ms preprocess, 55.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 93.1ms
# Speed: 1.8ms preprocess, 93.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 70.1ms
# Speed: 1.3ms preprocess, 70.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.1ms
# Speed: 1.0ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.5ms
# Speed: 1.2ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.7ms
# Speed: 1.2ms preprocess, 55.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 71.4ms
# Speed: 1.1ms preprocess, 71.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 56.1ms
# Speed: 1.1ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.6ms
# Speed: 1.2ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.2ms
# Speed: 1.2ms preprocess, 54.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.7ms
# Speed: 1.1ms preprocess, 55.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 72.8ms
# Speed: 1.1ms preprocess, 72.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.8ms
# Speed: 1.0ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.2ms
# Speed: 1.2ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 54.3ms
# Speed: 1.1ms preprocess, 54.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 98.4ms
# Speed: 1.1ms preprocess, 98.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 52.4ms
# Speed: 1.4ms preprocess, 52.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.2ms
# Speed: 1.1ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.0ms
# Speed: 1.2ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 chair, 55.1ms
# Speed: 1.2ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# Selesai memproses video!
#                          video  frame  timestamp_sec  person_count
# 291  interview_question_1.webm    292       17.60804             2

# %%
def format_timestamp(seconds):
    m = int(seconds // 60)
    s = int(seconds % 60)
    return f"{m:02d}:{s:02d}"

df_multi_person["timestamp_formatted"] = df_multi_person["timestamp_sec"].apply(format_timestamp)

df_multi_person.head()
# Out:
#                          video  frame  timestamp_sec  person_count  \
# 291  interview_question_1.webm    292       17.60804             2
#
#     timestamp_formatted
# 291               00:17

# %%
df = pd.DataFrame(results_summary)
df.head()
# Out:
#                        video  frame  timestamp_sec  person_count
# 0  interview_question_1.webm      1       0.060302             1
# 1  interview_question_1.webm      2       0.120603             1
# 2  interview_question_1.webm      3       0.180905             1
# 3  interview_question_1.webm      4       0.241206             1
# 4  interview_question_1.webm      5       0.301508             1

# %%
df.to_csv("people_detection_video_results.csv", index=False)
print("Saved → people_detection_video_results.csv")
# Out:
# Saved → people_detection_video_results.csv

# %%
df_summary = df.groupby("video")["person_count"].agg(
    total_frames="count",
    max_person="max",
    avg_person="mean"
)

df_summary
# Out:
#                            total_frames  max_person  avg_person
# video
# interview_question_1.webm          1544           2    1.000648
